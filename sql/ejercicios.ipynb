# %% [markdown]
# # Ejercicios diarios mySQL

# %% [markdown]
# ## Importacion de los datos y librerias

# %%
## Conectarse a docker y pandas
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
from dotenv import load_dotenv
import cryptography
load_dotenv("credenciales_mysql.env")
# Out:
# True

# %% [markdown]
# ## Creacion usuario para conectarse a base de datos

# %%
user = os.getenv("MYSQL_USER", "root")
pwd  = os.environ["MYSQL_PASSWORD"]
host = os.getenv("MYSQL_HOST", "127.0.0.1")
port = os.getenv("MYSQL_PORT", "3306")
db   = os.getenv("MYSQL_DB", "sakila")

engine = create_engine(f"mysql+pymysql://{user}:{pwd}@{host}:{port}/{db}")

# %%
print("cwd:", os.getcwd())
print("MYSQL_USER:", os.getenv("MYSQL_USER"))
print("MYSQL_PASSWORD existe?:", os.getenv("MYSQL_PASSWORD") is not None)
print("MYSQL_DB existe?:", os.getenv("MYSQL_DB"))
print("MYSQL_ROOT_PASSWORD existe?:", os.getenv("MYSQL_ROOT_PASSWORD") is not None)
# Out:
# cwd: c:\Users\workw\Documents\practicar programacion\sql
# MYSQL_USER: app
# MYSQL_PASSWORD existe?: True
# MYSQL_DB existe?: sakila
# MYSQL_ROOT_PASSWORD existe?: True

# %% [markdown]
# ## Practica clausulas y operadores

# %%
df = pd.read_sql("SELECT category, COUNT(*) AS n FROM film_list GROUP BY category ORDER BY n DESC;", engine)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\workw\Documents\practicar programacion\python\.venv\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\workw\Documents\practicar programacion\python\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# ...

# %%
pd.read_sql("SHOW TABLES;", engine)
# Out:
# Empty DataFrame
# Columns: [Tables_in_sakila]
# Index: []

# %%
pd.read_sql("DESCRIBE film_list;", engine)

# %%
pd.read_sql("SELECT title FROM film_list;", engine)

# %%
pd.read_sql("SELECT title FROM film_list WHERE category = 'Documentary';", engine)

# %%
pd.read_sql("SELECT * FROM film_list WHERE price BETWEEN 1 AND 3;", engine)

# %%
pd.read_sql("SELECT * FROM film_list WHERE price > 1 AND price < 3;", engine)

# %%
pd.read_sql("DESCRIBE actor_info;", engine)

# %%
pd.read_sql("DESCRIBE country;", engine)

# %%
# No olvidar poner comillas al dato de la variable categorica (no olvidar poner comillas a Algeria)
pd.read_sql("SELECT * FROM country WHERE country != 'Algeria';", engine)

# %%
pd.read_sql("SELECT * FROM country WHERE country <> 'Algeria';", engine)

# %%
pd.read_sql("SELECT * FROM country WHERE country NOT IN ('Algeria', 'ARGENTINA');", engine)
