# %%
import pandas as pd

# %%
arr1 = [i for i in range(10000+1)]
arr2= [f"x_{i}" for i in range(len(arr1))]

myvar = pd.Series(arr1, index = arr2)

print(myvar)
# Out:
# x_0            0
# x_1            1
# x_2            2
# x_3            3
# x_4            4
#            ...
# x_9996      9996
# x_9997      9997
# x_9998      9998
# x_9999      9999
# x_10000    10000
# Length: 10001, dtype: int64

# %%
df = pd.DataFrame({'X':[78,78,85,96,80,86], 'Y':[84,84,94,89,83,86],'Z':[86,86,97,96,72,83]})
df.head()
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  78  84  86
# 2  85  94  97
# 3  96  89  96
# 4  80  83  72

# %%
df.value_counts(dropna=False)
# Out:
# X   Y   Z
# 78  84  86    2
# 85  94  97    1
# 96  89  96    1
# 80  83  72    1
# 86  86  83    1
# Name: count, dtype: int64
